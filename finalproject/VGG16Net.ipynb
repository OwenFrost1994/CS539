#   inflating: dataimgs/shale/h90.JPG
#   inflating: dataimgs/shale/h91.JPG
#   inflating: dataimgs/shale/h92.JPG
#   inflating: dataimgs/shale/h93.JPG
#   inflating: dataimgs/shale/h94.JPG
#   inflating: dataimgs/shale/h95.JPG
#   inflating: dataimgs/shale/h96.JPG
#   inflating: dataimgs/shale/h97.JPG
#   inflating: dataimgs/shale/h98.JPG
#   inflating: dataimgs/shale/h99.JPG

# %%
from glob import glob
from sklearn.model_selection import train_test_split

dirs = glob('DataVGG/*')
print(dirs)
carbonate = glob('DataVGG/carbonate/*.JPG')
igneous = glob('DataVGG/igneous/*.JPG')
sandstone = glob('DataVGG/sandstone/*.JPG')
shale = glob('DataVGG/shale/*.JPG')

# Split into train and test sets.
carbonate_train, carbonate_test = train_test_split(carbonate, test_size=0.2)
igneous_train, igneous_test = train_test_split(igneous, test_size=0.2)
sandstone_train, sandstone_test = train_test_split(sandstone, test_size=0.2)
shale_train, shale_test = train_test_split(shale, test_size=0.2)

carbonate_train, carbonate_val = train_test_split(carbonate_train, test_size=0.3)
igneous_train, igneous_val = train_test_split(igneous_train, test_size=0.3)
sandstone_train, sandstone_val = train_test_split(sandstone_train, test_size=0.3)
shale_train, shale_val = train_test_split(shale_train, test_size=0.3)
# Out:
# ['DataVGG/shale', 'DataVGG/sandstone', 'DataVGG/carbonate', 'DataVGG/igneous']

# %%
# This code moves the validation files out of the train directory and over to 
# the val directory.
# !rm -rf DataVGG/val
# !mkdir DataVGG/val
# !rm -rf DataVGG/test
# !mkdir DataVGG/test
# !rm -rf DataVGG/train
# !mkdir DataVGG/train

# !mkdir DataVGG/val/carbonate
files = ' '.join(carbonate_val)
# !mv -t DataVGG/val/carbonate $files

# !mkdir DataVGG/val/igneous
files = ' '.join(igneous_val)
# !mv -t DataVGG/val/igneous $files

# !mkdir DataVGG/val/sandstone
files = ' '.join(sandstone_val)
# !mv -t DataVGG/val/sandstone $files

# !mkdir DataVGG/val/shale
files = ' '.join(shale_val)
# !mv -t DataVGG/val/shale $files

# !mkdir DataVGG/test/carbonate
files = ' '.join(carbonate_test)
# !mv -t DataVGG/test/carbonate $files

# !mkdir DataVGG/test/igneous
files = ' '.join(igneous_test)
# !mv -t DataVGG/test/igneous $files

# !mkdir DataVGG/test/sandstone
files = ' '.join(sandstone_test)
# !mv -t DataVGG/test/sandstone $files

# !mkdir DataVGG/test/shale
files = ' '.join(shale_test)
# !mv -t DataVGG/test/shale $files

# !mkdir DataVGG/train/carbonate
files = ' '.join(carbonate_train)
# !mv -t DataVGG/train/carbonate $files

# !mkdir DataVGG/train/igneous
files = ' '.join(igneous_train)
# !mv -t DataVGG/train/igneous $files

# !mkdir DataVGG/train/sandstone
files = ' '.join(sandstone_train)
# !mv -t DataVGG/train/sandstone $files

# !mkdir DataVGG/train/shale
files = ' '.join(shale_train)
# !mv -t DataVGG/train/shale $files

# !rmdir DataVGG/carbonate
# !rmdir DataVGG/igneous
# !rmdir DataVGG/sandstone
# !rmdir DataVGG/shale

# %%
# Jupyter keeps checkpoint files that may screw up the ImageDataGenerator class
# So we delete those here. 
# !rm -rf train/.ipynb_checkpoints
# !rm -rf val/.ipynb_checkpoints

# %% [markdown]
# ## Augment Data for Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import preprocess_input

TRAIN_DIR = 'DataVGG/train'
VAL_DIR = 'DataVGG/val'
WIDTH = 299
HEIGHT = 299
BATCH_SIZE = 10

# data prep
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=90,
    zoom_range=[1,2],
    horizontal_flip=True,
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=90,
    zoom_range=[1,2],
    horizontal_flip=True,
    fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(HEIGHT, WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
    
validation_generator = validation_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(HEIGHT, WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/hp/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 407 images belonging to 4 classes.
# Found 177 images belonging to 4 classes.

# %% [markdown]
# ## Load Pre-trained model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

base_model = VGG16(weights='imagenet', include_top=False)

# %% [markdown]
# ## Replace classification layer

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout


CLASSES = 4
# These layers were removed by setting include_top=false, but we still want them
x = base_model.output                          # The output layer of the googleNet
x = GlobalAveragePooling2D(name='avg_pool')(x) # This layer is used to downsample the features
x = Dropout(0.4)(x)                            # This layer is used to enforce feature redundancy 

# This layer specifies our classifier output
predictions = Dense(CLASSES, activation='softmax')(x)
#
model = Model(inputs=base_model.input, outputs=predictions)

# %%
for layer in base_model.layers:
    layer.trainable = False # Set this to True if you want to re-train the entire network.

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Train the network

# %%
EPOCHS = 40
BATCH_SIZE = 20
STEPS_PER_EPOCH = 5
VALIDATION_STEPS = 2
MODEL_FILE = 'VGG16.model'

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=validation_generator,
    validation_steps=VALIDATION_STEPS)
  ## Test Trained Network
model.save(MODEL_FILE)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 77s 15s/step - loss: 1.7343 - accuracy: 0.2800 - val_loss: 1.3477 - val_accuracy: 0.3000
# Epoch 2/40
# 5/5 [==============================] - 71s 14s/step - loss: 1.5877 - accuracy: 0.2200 - val_loss: 1.3365 - val_accuracy: 0.4000
# Epoch 3/40
# 5/5 [==============================] - 71s 14s/step - loss: 1.6146 - accuracy: 0.1800 - val_loss: 1.3695 - val_accuracy: 0.3000
# Epoch 4/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.3118 - accuracy: 0.4800 - val_loss: 1.3907 - val_accuracy: 0.3000
# Epoch 5/40
# 5/5 [==============================] - 71s 14s/step - loss: 1.3699 - accuracy: 0.3200 - val_loss: 1.3533 - val_accuracy: 0.3500
# Epoch 6/40
# 5/5 [==============================] - 71s 14s/step - loss: 1.4427 - accuracy: 0.2200 - val_loss: 1.3729 - val_accuracy: 0.4000
# Epoch 7/40
# 5/5 [==============================] - 67s 13s/step - loss: 1.4010 - accuracy: 0.3191 - val_loss: 1.3261 - val_accuracy: 0.4500
# Epoch 8/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.4379 - accuracy: 0.2800 - val_loss: 1.3775 - val_accuracy: 0.3500
# Epoch 9/40
# 5/5 [==============================] - 74s 15s/step - loss: 1.2327 - accuracy: 0.5000 - val_loss: 1.4017 - val_accuracy: 0.3500
# Epoch 10/40
# 5/5 [==============================] - 68s 14s/step - loss: 1.4005 - accuracy: 0.3191 - val_loss: 1.4153 - val_accuracy: 0.3500
# Epoch 11/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.3619 - accuracy: 0.4200 - val_loss: 1.3342 - val_accuracy: 0.5000
# Epoch 12/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.4402 - accuracy: 0.3800 - val_loss: 1.3348 - val_accuracy: 0.5000
# Epoch 13/40
# 5/5 [==============================] - 71s 14s/step - loss: 1.3433 - accuracy: 0.3400 - val_loss: 1.3336 - val_accuracy: 0.3500
# Epoch 14/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.2786 - accuracy: 0.4000 - val_loss: 1.3347 - val_accuracy: 0.3500
# Epoch 15/40
# 5/5 [==============================] - 69s 14s/step - loss: 1.3144 - accuracy: 0.3800 - val_loss: 1.3210 - val_accuracy: 0.5000
# Epoch 16/40
# 5/5 [==============================] - 69s 14s/step - loss: 1.3968 - accuracy: 0.2800 - val_loss: 1.3728 - val_accuracy: 0.3500
# Epoch 17/40
# 5/5 [==============================] - 73s 15s/step - loss: 1.3554 - accuracy: 0.4000 - val_loss: 1.3672 - val_accuracy: 0.2500
# Epoch 18/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.3529 - accuracy: 0.3000 - val_loss: 1.3675 - val_accuracy: 0.3000
# Epoch 19/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2092 - accuracy: 0.4600 - val_loss: 1.3143 - val_accuracy: 0.5000
# Epoch 20/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2199 - accuracy: 0.4600 - val_loss: 1.3268 - val_accuracy: 0.4000
# Epoch 21/40
# 5/5 [==============================] - 67s 13s/step - loss: 1.3041 - accuracy: 0.4681 - val_loss: 1.2977 - val_accuracy: 0.4500
# Epoch 22/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.3853 - accuracy: 0.3400 - val_loss: 1.3013 - val_accuracy: 0.4500
# Epoch 23/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.3737 - accuracy: 0.2800 - val_loss: 1.2633 - val_accuracy: 0.5000
# Epoch 24/40
# 5/5 [==============================] - 69s 14s/step - loss: 1.3523 - accuracy: 0.4200 - val_loss: 1.2760 - val_accuracy: 0.5500
# Epoch 25/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.1666 - accuracy: 0.5200 - val_loss: 1.3237 - val_accuracy: 0.4500
# Epoch 26/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2656 - accuracy: 0.3400 - val_loss: 1.2828 - val_accuracy: 0.4500
# Epoch 27/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2354 - accuracy: 0.4200 - val_loss: 1.2734 - val_accuracy: 0.5000
# Epoch 28/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.1492 - accuracy: 0.5600 - val_loss: 1.2304 - val_accuracy: 0.6500
# Epoch 29/40
# 5/5 [==============================] - 67s 13s/step - loss: 1.1894 - accuracy: 0.5532 - val_loss: 1.2539 - val_accuracy: 0.4500
# Epoch 30/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2598 - accuracy: 0.4000 - val_loss: 1.3346 - val_accuracy: 0.3500
# Epoch 31/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2638 - accuracy: 0.4800 - val_loss: 1.3547 - val_accuracy: 0.3000
# Epoch 32/40
# 5/5 [==============================] - 69s 14s/step - loss: 1.2535 - accuracy: 0.5000 - val_loss: 1.3383 - val_accuracy: 0.3500
# Epoch 33/40
# 5/5 [==============================] - 72s 14s/step - loss: 1.2236 - accuracy: 0.5000 - val_loss: 1.2767 - val_accuracy: 0.4500
# Epoch 34/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2589 - accuracy: 0.4600 - val_loss: 1.2798 - val_accuracy: 0.4000
# Epoch 35/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2588 - accuracy: 0.4400 - val_loss: 1.2864 - val_accuracy: 0.3000
# Epoch 36/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2365 - accuracy: 0.4400 - val_loss: 1.1945 - val_accuracy: 0.5500
# Epoch 37/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.3541 - accuracy: 0.3000 - val_loss: 1.2594 - val_accuracy: 0.5000
# Epoch 38/40
# 5/5 [==============================] - 67s 13s/step - loss: 1.1736 - accuracy: 0.5106 - val_loss: 1.2926 - val_accuracy: 0.3500
# Epoch 39/40
# 5/5 [==============================] - 70s 14s/step - loss: 1.2144 - accuracy: 0.4800 - val_loss: 1.2550 - val_accuracy: 0.4500
# Epoch 40/40
# 5/5 [==============================] - 69s 14s/step - loss: 1.1365 - accuracy: 0.5800 - val_loss: 1.3272 - val_accuracy: 0.4500

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs = range(1,len(acc)+1)

plt.plot(epochs, val_acc,'r')
plt.plot(epochs, acc,'r.')
plt.title("Training Accuracy")

plt.figure()
plt.plot(epochs, val_loss,'r')
plt.plot(epochs,loss,'r.')
plt.title("Training Loss")
plt.show()
# Out:
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
max(val_acc)
# Out:
# 0.65

# %% [markdown]
# ## Test Trained Network

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import seaborn as sn

# %%
from glob import glob
carbonate_test = glob('DataVGG/test/carbonate/*.JPG')
igneous_test = glob('DataVGG/test/igneous/*.JPG')
sandstone_test = glob('DataVGG/test/sandstone/*.JPG')
shale_test = glob('DataVGG/test/shale/*.JPG')

# %%
# data prep
TEST_DIR = 'DataVGG/test'
WIDTH = 299
HEIGHT = 299

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,fill_mode='nearest')
test_generator = validation_datagen.flow_from_directory(TEST_DIR,target_size=(HEIGHT, WIDTH),class_mode='categorical')
# Out:
# Found 149 images belonging to 4 classes.

# %%
model = load_model(MODEL_FILE)

# %%
pred_label = list()
for i in range(len(test_generator.filenames)):
    img = image.load_img(test_generator.directory+'/'+test_generator.filenames[i], target_size=(HEIGHT, WIDTH))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    pred_label.append(np.argmax(model.predict(x)[0]))

# %%
pred_labels = np.array(pred_label).astype(np.int32)

# %%
#plot confusion matrix
c_mat = np.zeros((4,4))
for i in range(test_generator.labels.shape[0]):
    c_mat[pred_labels[i], test_generator.labels[i]] += 1

print("Confusion matrix:\n" + str(c_mat))

group_counts = ["{0:0.0f}".format(value) for value in c_mat.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in c_mat.flatten()/np.sum(c_mat)]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(c_mat.shape[0], c_mat.shape[1])

accuracy = (np.sum(np.logical_and(pred_labels, test_generator.labels))/ len(test_generator.labels)) * 100

plt.figure(figsize=(12,10))
sn.heatmap(c_mat, annot=labels, fmt='', cmap='rocket_r')
plt.title("Confusion Matrix")
plt.ylabel('Output Class')
_ = plt.xlabel('Target Class \n Accuracy: ' + '%.2f'%accuracy + "%")
# Out:
# Confusion matrix:
# [[ 1.  0.  0.  0.]
#  [32. 33. 35. 18.]
#  [ 0.  0.  2.  0.]
#  [ 1.  4. 10. 13.]]
